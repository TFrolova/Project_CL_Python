# %% [markdown]
# <a href="https://colab.research.google.com/github/TFrolova/Project_CL_Python/blob/main/Le_petit_prince_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Первая серия упражнений с файлом "Маленький принц"
#
# 1. Посчитать частоты слов в этом тексте и упорядочить список по частоте. Для этого берем слова в поле KSNAME либо LEMMA с непустым содержимым тега W; счетчик - это тетрадка 9, искать по слову counter
# 2. Посчитать частоты слов в корпусе СинТагРус, сравнить с частотами "Маленького принца" и определить, какие слова характерны для рассматриваемого текста; а как сравнивать? Видимо, надо искать по словам tf-idf
# 3. Нарисовать для полученного результата картинку (диаграмму с кружочками)
# 4. Повторить процедуру для связей. Получится ли что-то интересное из анализа связей

# %%
# извлечем список слов из поля LEMMA и запомним его в переменную
#prince_lemmas =

# %%
# сначала открываем файл
with open ('/content/drive/MyDrive/texts/Malenkii_prints_copy_1.txt', 'r', encoding='UTF8') as f:
  p_text=f.read()
print(p_text[:20])
# Out:
# ﻿<?xml version="1.0"

# %%
# библиотека для работы с xml
import xml.etree.ElementTree as ET

# %%
# прочитали и сделали дерево из большого файла (= "распарсили")
tree = ET.parse('/content/drive/MyDrive/texts/Malenkii_prints_copy_1.txt')

# %%
# находим главный тег и проверяем, как он называется
root = tree.getroot()
root.tag
# Out:
# 'text'

# %%
# Какие есть теги внутри главного
# можно не запускать
for child in root:
     print(child.tag)
# Out:
# inf
# body

# %%
# сохраним содержимое второго тега (body) в переменную body (по названию тега)
# нужно запустить один раз
body = root[1]

# %%
# Какие есть теги внутри body
# можно не запускать
for b_child in body:
     print(b_child.tag)
# Out:
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S
# S

# %%
# как называется первый тег внутри body
print(body[0].tag)
# Out:
# S

# %%
# посмотрим на теги внутри первого S
first_sentence = body[0]
for s_child in first_sentence:
  print(s_child.tag)
# Out:
# W
# W
# W
# SEM

# %%
# внутри W тегов нет, есть атрибуты, они устроены как словарь
first_word = first_sentence[0]
print(first_word.attrib)
#for w_child in first_word:
#  print(w_child.attrib)
# Out:
# {'DOM': '_root', 'EXTRAFEAT': 'CAP ЗЕРО', 'FEAT': 'S ЕД МУЖ ИМ ОД', 'HYPOT': 'root', 'ID': '1', 'KSNAME': 'АНТУАН', 'LEMMA': 'АНТУАН'}

# %%
# в атрибуте LEMMA лежит имя леммы, оно мне и нужно
# пробуем вытащить значение по ключу
first_word.attrib['LEMMA']
# Out:
# 'АНТУАН'

# %%
# заводим список, в который будем сохранять леммы
prince_lemmas = []

# %%
# на случай если понадобится список всех тегов W
prince_words = []

# %%
# проверяю, что так сработает цикл с i
for i in range(0, 4):
  print(first_sentence[i].tag)
# Out:
# W
# W
# W
# SEM

# %%
# теперь нужно сделать цикл, который извлекает все леммы из слов одного предложения
for i in range(0, 4):
  if first_sentence[i].tag == 'W':
    prince_lemmas.append(first_sentence[i].attrib['LEMMA'])

print(prince_lemmas)
# Out:
# ['АНТУАН', 'ДЕ', 'СЕНТ-ЭКЗЮПЕРИ']

# %%
# как задать range?
for i in range(len(first_sentence)):
  if first_sentence[i].tag == 'W':
    prince_lemmas.append(first_sentence[i].attrib['LEMMA'])

print(prince_lemmas)
# Out:
# ['АНТУАН', 'ДЕ', 'СЕНТ-ЭКЗЮПЕРИ']

# %%
# теперь нужно сделать цикл, который извлекает все леммы из всех слов всех предложений
# бывают ли пустые леммы? если есть, есть ли проблема записать их в список?
# попробуем  засунуть цикл из предыдущей ячейки в функцию
def find_lemmas(j):
  for i in range(len(body[j])):
    if body[j][i].tag == 'W':
      prince_lemmas.append(body[j][i].attrib['LEMMA'])

# проверим, как она работает
find_lemmas(2)
print(prince_lemmas)
# Out:
# ['НОРА', 'ГАЛЬ', 'ПЕРЕВОД', 'НОРА', 'ГАЛЬ', 'ПЕРЕВОД']

# %%
# попробуем применить эту функцию ко всем предложениям текста
prince_lemmas = []
for j in range(len(body)):
   find_lemmas(j)
  
print(len(prince_lemmas))
# Out:
# 12256

# %%
# кажется, таким образом можно извлечь самые частотные слова из "Маленького принца"
from collections import Counter
Counter(prince_lemmas).most_common(50)
#print(Counter(full_text).most_common(50))
# Out:
# [('Я', 555),
#  ('И', 456),
#  ('ОН', 369),
#  ('НЕ', 329),
#  ('МАЛЕНЬКИЙ', 202),
#  ('БЫТЬ', 201),
#  ('ТЫ', 188),
#  ('НА', 182),
#  ('В', 181),
#  ('ПРИНЦ', 180),
#  ('ЧТО', 178),
#  ('ЭТО', 161),
#  ('СКАЗАТЬ', 135),
#  ('ОНИ', 132),
#  ('А', 126),
#  ('НО', 116),
#  ('КАК', 97),
#  ('У', 96),
#  ('ОНА', 93),
#  ('С', 88),
#  ('МОЙ', 78),
#  ('ОЧЕНЬ', 78),
#  ('ОДИН', 68),
#  ('ВЕСЬ', 65),
#  ('ПЛАНЕТА', 65),
#  ('ЭТОТ', 63),
#  ('ЕСЛИ', 58),
#  ('ТАК', 58),
#  ('КОГДА', 57),
#  ('ДА', 57),
#  ('ТАКОЙ', 56),
#  ('ВОТ', 54),
#  ('ВСЕ', 53),
#  ('О', 52),
#  ('МОЧЬ', 52),
#  ('ЧЕЛОВЕК', 52),
#  ('ЗВЕЗДА', 50),
#  ('ВЫ', 50),
#  ('ЖЕ', 49),
#  ('СПРАШИВАТЬ', 46),
#  ('НЕТ', 44),
#  ('СВОЙ', 43),
#  ('ЧТОБЫ', 43),
#  ('ЕЩЕ', 42),
#  ('ОТВЕЧАТЬ', 42),
#  ('ВИДЕТЬ', 41),
#  ('ЗНАТЬ', 41),
#  ('БАРАШЕК', 41),
#  ('ДЕНЬ', 41),
#  ('ВЕДЬ', 40)]

# %%
# имело бы смысл почистить список от стоп слов, но пока неясно, какие из них ненужные

# %%
# нарисуем облако слов (из тетрадки 11)
from wordcloud import WordCloud
import matplotlib.pyplot as plt
#%matplotlib inline

# Генерируем облако слов
wordcloud = WordCloud().generate(', '.join(prince_lemmas))
plt.imshow(wordcloud) # Что изображаем
plt.axis("off") # Без подписей на осях
plt.show() # показать изображение

# %%
from collections import Counter
c = Counter(prince_lemmas)
len(c.elements())
#for e in c.keys():
#  print(e, c.get(e))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-d6afd7209490> in <module>
#       1 from collections import Counter
#       2 c = Counter(prince_lemmas)
# ----> 3 len(c.elements())
#       4 #for e in c.keys():
#       5 #  print(e, c.get(e))
#
# TypeError: object of type 'itertools.chain' has no len()

# %%
#ipm
#     для каждого слова поделить его цифру из каунтера на 12256 (*1000000)

# %%
# tf-idf

# %%
# биграммы

# %%
# визуализация

# %%
# тетрадки "Copy of collocations_14/12" и "Collocations" (два экземпляра) и "Copy of TF-IDF"
